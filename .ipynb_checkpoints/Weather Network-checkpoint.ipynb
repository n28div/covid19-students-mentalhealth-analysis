# %%
import numpy as np
import matplotlib.pyplot as plt
from pgmpy.factors.discrete import State
from pgmpy.models import BayesianModel
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
from pgmpy.sampling import BayesianModelSampling

# Compare values down to 3rd digit
precision = 3

# Defining the network structure
weather = BayesianModel([('Cloudy', 'Rain'), ('Cloudy', 'Sprinkler'), ('Sprinkler', 'WetGrass'), ('Rain', 'WetGrass')])

# Defining the CPDs:
cpd_cloudy = TabularCPD('Cloudy', 2, [[.5,.5]])
cpd_sprinkler = TabularCPD('Sprinkler', 2, [[.1,.5],[.9,.5]], evidence = ['Cloudy'], evidence_card=[2])
cpd_rain = TabularCPD('Rain', 2, [[.8,.2],[.2,.8]], evidence = ['Cloudy'], evidence_card=[2])
cpd_wetgrass = TabularCPD('WetGrass', 2, [[.99,.9,.9,.01],[.01,.1,.1,.99]], evidence = ['Sprinkler','Rain'], evidence_card=[2,2])

weather.add_cpds(cpd_cloudy,cpd_sprinkler,cpd_rain,cpd_wetgrass)
# weather.get_cpds()
weather.check_model()

# Exact values of queries (for comparison)
inference = VariableElimination(weather)
pcloudy = inference.query(['Cloudy'],{'Sprinkler':1,'WetGrass':1}).values[1]
# print('P(Cloudy=true|Sprinkler=true,WetGrass=true) = ', round(pcloudy,precision))
prain = inference.query(['Rain'],{'Sprinkler':1,'WetGrass':1}).values[1]
# print('P(Rain=true|Sprinkler=true,WetGrass=true) = ', round(prain,precision))
# Out:
# Finding Elimination Order: : 100%|██████████| 1/1 [00:00<00:00, 745.79it/s]
# Eliminating: Rain: 100%|██████████| 1/1 [00:00<00:00, 619.18it/s]
# Finding Elimination Order: : 100%|██████████| 1/1 [00:00<00:00, 1348.22it/s]
# Eliminating: Cloudy: 100%|██████████| 1/1 [00:00<00:00, 685.01it/s]

# %%
# Now switch to sampling methods
inference = BayesianModelSampling(weather)
evidence = [State('WetGrass', 1),State('Sprinkler', 1)]
verbose = False

def prob_LW(samples,variable):
    return round(np.sum(np.dot(samples[variable],samples['_weight']))/np.sum(samples['_weight']),2)

def relative_error(exact_value,approx_value):
    return np.absolute((exact_value-approx_value)/exact_value)

def absolute_error(exact_value,approx_value):
    return np.absolute(exact_value-approx_value)

def run_experiment(sample_size):
    # Sample
    samples_LW = inference.likelihood_weighted_sample(evidence = evidence, size=sample_size, return_type='recarray')
    samples_RS = inference.rejection_sample(evidence=evidence, size=sample_size, return_type='recarray')

    # Statistics
    pcloudy_LW=prob_LW(samples_LW,'Cloudy')
    prain_LW=prob_LW(samples_LW,'Rain')
    pcloudy_RS=np.recarray.mean(samples_RS['Cloudy'], axis=0)
    prain_RS=np.recarray.mean(samples_RS['Rain'], axis=0)
    
    # Reporting
    if(verbose):
        print()
        print("P(Cloudy=true|Sprinkler=true,WetGrass=true) =", round(pcloudy,precision))
        print("With Rejection Sampling after %d samples: %.3f (error = %.2f percent)" 
              % (sample_size, pcloudy_RS, absolute_error(pcloudy,pcloudy_RS)*100))
        print("With Likelihood Weighting after %d samples: %.3f (error = %.2f percent)" 
              % (sample_size, pcloudy_LW, absolute_error(pcloudy,pcloudy_LW)*100))
        print()
        print("P(Rain=true|Sprinkler=true,WetGrass=true) =", round(prain,precision))
        print("With Rejection Sampling after %d samples: %.3f (error = %.2f percent)" 
              % (sample_size, prain_RS, absolute_error(prain,prain_RS)*100))
        print("With Likelihood Weighting after %d samples: %.3f (error = %.2f percent)" 
              % (sample_size, prain_LW, absolute_error(prain,prain_LW)*100))
    
    # Return results
    return np.array([(sample_size, 
                      pcloudy_RS, absolute_error(pcloudy,pcloudy_RS),
                      pcloudy_LW, absolute_error(pcloudy,pcloudy_LW),
                      prain_RS, absolute_error(prain,prain_RS),
                      prain_LW, absolute_error(prain,prain_LW))], 
                    dtype=[('sample_size', '<i8'), 
                           ('pcloudy_RS', '<f8'),('e_pcloudy_RS', '<f8'),
                           ('pcloudy_LW', '<f8'),('e_pcloudy_LW', '<f8'),
                           ('prain_RS', '<f8'),('e_prain_RS', '<f8'),
                           ('prain_LW', '<f8'),('e_prain_LW', '<f8')])

# To view samples
# print(samples_LW)
# samples_LW.view()
# print(samples_RS[:5]), print(' ... '), print(samples_RS[nsamples_RS-5:])

# %%
results = np.array([],dtype=[('sample_size', '<i8'), 
                             ('pcloudy_RS', '<f8'),('e_pcloudy_RS', '<f8'),
                             ('pcloudy_LW', '<f8'),('e_pcloudy_LW', '<f8'),
                             ('prain_RS', '<f8'),('e_prain_RS', '<f8'),
                             ('prain_LW', '<f8'),('e_prain_LW', '<f8')])
starting_size_=1 # from 10 sample points
final_size=5     # to 10^5 sample points
experiments=20 # 8 experiments

for size in np.logspace(starting_size_, final_size, num=experiments, dtype='<i8'):
    results=np.append(results,run_experiment(size))
    
print(results)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 491.52it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 434.02it/s]
# 15it [00:00, 689.66it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 389.59it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 378.79it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 382.70it/s]
# 20it [00:00, 526.47it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 339.52it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 407.41it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 462.37it/s]
# 100%|██████████| 26/26 [00:00<00:00, 714.78it/s]
#   0%|          | 0/42 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 298.82it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 260.67it/s]
# 48it [00:00, 1410.94it/s]
#   0%|          | 0/69 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 224.18it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 154.67it/s]
# 90it [00:00, 1867.60it/s]
#   0%|          | 0/112 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 180.64it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 121.41it/s]
# 151it [00:00, 2504.62it/s]
#   0%|          | 0/183 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 128.15it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 105.99it/s]
# 227it [00:00, 3112.15it/s]
#   0%|          | 0/297 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 88.12it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 79.32it/s]
# 359it [00:00, 3552.90it/s]
#   0%|          | 0/483 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 57.25it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 40.17it/s]
# 617it [00:00, 3545.77it/s]
#   0%|          | 0/784 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 37.37it/s]
#  49%|████▉     | 386/784 [00:00<00:00, 3548.41it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 27.95it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 24.80it/s]
# 964it [00:00, 3530.23it/s]
#   0%|          | 0/1274 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 26.06it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 22.96it/s]
#  51%|█████     | 647/1274 [00:00<00:00, 3667.99it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 18.12it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 16.22it/s]
# 1597it [00:00, 3740.61it/s]
#   0%|          | 0/2069 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 16.71it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00, 14.60it/s]
#  49%|████▉     | 1013/2069 [00:00<00:00, 3664.77it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00, 12.59it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00, 12.59it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 10.04it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00, 10.04it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00,  8.89it/s]
# 2602it [00:00, 3558.17it/s]
#   0%|          | 0/3359 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00, 13.43it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00, 13.43it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00, 10.25it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00, 10.25it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00,  9.03it/s]
#  48%|████▊     | 1624/3359 [00:00<00:00, 3639.00it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  8.99it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  8.99it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00,  6.98it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00,  6.98it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00,  6.25it/s]
# 4288it [00:01, 3936.14it/s]
#   0%|          | 0/5455 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  9.54it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  9.54it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00,  7.53it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00,  7.53it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00,  6.46it/s]
#  50%|████▉     | 2712/5455 [00:00<00:00, 4368.49it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  6.39it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  6.39it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00,  4.90it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00,  4.90it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:00<00:00,  4.28it/s]
# 6877it [00:01, 4407.06it/s]
#   0%|          | 0/8858 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  5.92it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  5.92it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:00<00:00,  4.57it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:00<00:00,  4.57it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:01<00:00,  3.97it/s]
#  49%|████▊     | 4312/8858 [00:01<00:01, 4275.50it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  3.73it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  3.73it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:01<00:00,  2.86it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:01<00:00,  2.86it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# 11396it [00:02, 4402.21it/s]
#   0%|          | 0/14384 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  3.86it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  3.86it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:01<00:00,  2.91it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:01<00:00,  2.91it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
#  49%|████▊     | 6987/14384 [00:01<00:01, 4362.17it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  2.40it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  2.40it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:01<00:00,  1.80it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:01<00:00,  1.80it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:02<00:00,  1.54it/s]
# 18163it [00:04, 4317.24it/s]
#   0%|          | 0/23357 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:00<00:00,  2.38it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:00<00:00,  2.38it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:01<00:00,  1.79it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:01<00:00,  1.79it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:02<00:00,  1.53it/s]
#  50%|████▉     | 11568/23357 [00:02<00:02, 4407.29it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:01<00:01,  1.46it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:01<00:01,  1.46it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:02<00:00,  1.14it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:02<00:00,  1.14it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:04<00:00,  1.01s/it]
# 28981it [00:06, 4356.26it/s]
#   0%|          | 0/37926 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:01<00:01,  1.44it/s]
# Generating for node: Rain:  50%|█████     | 2/4 [00:01<00:01,  1.44it/s]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:02<00:00,  1.11it/s]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:02<00:00,  1.11it/s]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:04<00:00,  1.05s/it]
#  49%|████▉     | 18519/37926 [00:04<00:04, 4392.71it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:02<00:02,  1.11s/it]
# Generating for node: Rain:  50%|█████     | 2/4 [00:02<00:02,  1.11s/it]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:04<00:01,  1.43s/it]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:04<00:01,  1.43s/it]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it]
# 47878it [00:10, 4405.06it/s]
#   0%|          | 0/61584 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:02<00:02,  1.14s/it]
# Generating for node: Rain:  50%|█████     | 2/4 [00:02<00:02,  1.14s/it]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:04<00:01,  1.49s/it]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:04<00:01,  1.49s/it]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:06<00:00,  1.73s/it]
#  49%|████▉     | 30183/61584 [00:06<00:07, 4371.39it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:03<00:03,  1.72s/it]
# Generating for node: Rain:  50%|█████     | 2/4 [00:03<00:03,  1.72s/it]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:07<00:02,  2.28s/it]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:07<00:02,  2.28s/it]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:10<00:00,  2.62s/it]
# 77445it [00:17, 4448.92it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:03<00:03,  1.78s/it]
# Generating for node: Rain:  50%|█████     | 2/4 [00:03<00:03,  1.78s/it]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:07<00:02,  2.35s/it]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:07<00:02,  2.35s/it]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:10<00:00,  2.73s/it]
#  49%|████▉     | 49067/100000 [00:10<00:11, 4493.54it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Cloudy:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating for node: Sprinkler:  50%|█████     | 2/4 [00:05<00:05,  2.83s/it]
# Generating for node: Rain:  50%|█████     | 2/4 [00:05<00:05,  2.83s/it]
# Generating for node: Rain:  75%|███████▌  | 3/4 [00:11<00:03,  3.68s/it]
# Generating for node: WetGrass:  75%|███████▌  | 3/4 [00:11<00:03,  3.68s/it]
# Generating for node: WetGrass: 100%|██████████| 4/4 [00:16<00:00,  4.22s/it]
# 125651it [00:27, 4520.14it/s]
# [(    10, 0.5       , 0.11871381, 0.55, 0.06871381, 0.8       , 0.0750381 , 0.94, 0.0649619)
#  (    16, 0.625     , 0.00628619, 0.75, 0.13128619, 0.8125    , 0.0625381 , 0.9 , 0.0249619)
#  (    26, 0.73076923, 0.11205542, 0.59, 0.02871381, 0.88461538, 0.00957729, 0.88, 0.0049619)
#  (    42, 0.66666667, 0.04795286, 0.64, 0.02128619, 0.95238095, 0.07734285, 0.84, 0.0350381)
#  (    69, 0.76811594, 0.14940214, 0.73, 0.11128619, 0.91304348, 0.03800538, 0.84, 0.0350381)
#  (   112, 0.61607143, 0.00264238, 0.54, 0.07871381, 0.88392857, 0.00889047, 0.87, 0.0050381)
#  (   183, 0.59562842, 0.02308539, 0.65, 0.03128619, 0.87978142, 0.00474332, 0.9 , 0.0249619)
#  (   297, 0.5959596 , 0.02275421, 0.64, 0.02128619, 0.87878788, 0.00374978, 0.86, 0.0150381)
#  (   483, 0.64389234, 0.02517853, 0.6 , 0.01871381, 0.87991718, 0.00487909, 0.86, 0.0150381)
#  (   784, 0.64158163, 0.02286783, 0.67, 0.05128619, 0.86989796, 0.00514014, 0.86, 0.0150381)
#  (  1274, 0.61459969, 0.00411412, 0.6 , 0.01871381, 0.86342229, 0.01161581, 0.88, 0.0049619)
#  (  2069, 0.62252296, 0.00380915, 0.61, 0.00871381, 0.87626873, 0.00123063, 0.88, 0.0049619)
#  (  3359, 0.6108961 , 0.00781771, 0.62, 0.00128619, 0.87377196, 0.00126614, 0.88, 0.0049619)
#  (  5455, 0.62419798, 0.00548418, 0.61, 0.00871381, 0.8751604 , 0.00012231, 0.87, 0.0050381)
#  (  8858, 0.61481147, 0.00390234, 0.62, 0.00128619, 0.87333484, 0.00170326, 0.87, 0.0050381)
#  ( 14384, 0.62124583, 0.00253202, 0.62, 0.00128619, 0.87548665, 0.00044855, 0.88, 0.0049619)
#  ( 23357, 0.6189151 , 0.00020129, 0.62, 0.00128619, 0.87442737, 0.00061073, 0.87, 0.0050381)
#  ( 37926, 0.62102515, 0.00231135, 0.62, 0.00128619, 0.87625903, 0.00122093, 0.88, 0.0049619)
#  ( 61584, 0.61832619, 0.00038762, 0.61, 0.00871381, 0.8762828 , 0.0012447 , 0.87, 0.0050381)
#  (100000, 0.61915   , 0.00043619, 0.62, 0.00128619, 0.87599   , 0.0009519 , 0.88, 0.0049619)]

# %%
plt.figure(figsize=(20,5))
plt.subplot(121)
plt.ylim(0.5,1)
plt.title('P(Cloudy=true|Sprinkler=true,WetGrass=true)')
LWCplot, = plt.semilogx(results['sample_size'],results['pcloudy_LW'],'b',label="Likelihood Weighting")
RSCplot, = plt.semilogx(results['sample_size'],results['pcloudy_RS'],'g',label="Rejection Sampling")
VECplot, = plt.semilogx(results['sample_size'],pcloudy*np.ones(results.size),'r',label="reference value")
plt.legend(handles=[LWCplot,RSCplot,VECplot])
plt.subplot(122)
plt.ylim(0.5,1)
plt.title('P(Rain=true|Sprinkler=true,WetGrass=true)')
LWCplot, = plt.semilogx(results['sample_size'],results['prain_LW'],'b',label="Likelihood Weighting")
RSCplot, = plt.semilogx(results['sample_size'],results['prain_RS'],'g',label="Rejection Sampling")
VECplot, = plt.semilogx(results['sample_size'],prain*np.ones(results.size),'r',label="reference value")
plt.legend(handles=[LWCplot,RSCplot,VECplot])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(121)
plt.ylim(0,.1)
plt.title('Absolute error on P(Cloudy=true|Sprinkler=true,WetGrass=true)')
ELWCplot, = plt.semilogx(results['sample_size'],results['e_pcloudy_LW'],'b',label="Likelihood Weighting")
ERSCplot, = plt.semilogx(results['sample_size'],results['e_pcloudy_RS'],'g',label="Rejection Sampling")
plt.legend(handles=[ELWCplot,ERSCplot])
plt.subplot(122)
plt.ylim(0,.11)
plt.title('Absolute error on P(Rain=true|Sprinkler=true,WetGrass=true)')
ELWCplot, = plt.semilogx(results['sample_size'],results['e_prain_LW'],'b',label="Likelihood Weighting")
ERSCplot, = plt.semilogx(results['sample_size'],results['e_prain_RS'],'g',label="Rejection Sampling")
plt.legend(handles=[ELWCplot,ERSCplot])
plt.show()

# %%
weather.get_markov_blanket('Cloudy')
# Out:
# ['Rain', 'Sprinkler']

# %%
weather.get_markov_blanket('Rain')
# Out:
# ['Cloudy', 'Sprinkler', 'WetGrass']
